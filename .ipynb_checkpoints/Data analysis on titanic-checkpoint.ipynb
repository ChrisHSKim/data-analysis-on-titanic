# %% [markdown]
# ## 1. Imports

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

from sklearn import preprocessing

import missingno as msno
import warnings

plt.style.use('seaborn')
sns.set(font_scale = 1.2, style='white', context='notebook', palette='deep')
pylab.rcParams['figure.figsize'] = 12,8
warnings.filterwarnings('ignore')
mpl.style.use('ggplot')
sns.set_style('white')
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# ## 2. Exploratory Data Analysis(EDA)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %% [markdown]
# ### Types of features
# #### Categorical features:
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as Nominal Variables.
# #### Ordinal features:
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like Height with values Tall, Medium, Short, then Height is a ordinal variable. Here we can have a relative sort in the variable.
# #### Continuous features:
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
for col in df_train.columns:
    msg = 'column: {:<11}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column: Survived   	 Percent of NaN value: 0.00%
# column: Pclass     	 Percent of NaN value: 0.00%
# column: Name       	 Percent of NaN value: 0.00%
# column: Sex        	 Percent of NaN value: 0.00%
# column: Age        	 Percent of NaN value: 19.87%
# column: SibSp      	 Percent of NaN value: 0.00%
# column: Parch      	 Percent of NaN value: 0.00%
# column: Ticket     	 Percent of NaN value: 0.00%
# column: Fare       	 Percent of NaN value: 0.00%
# column: Cabin      	 Percent of NaN value: 77.10%
# column: Embarked   	 Percent of NaN value: 0.22%

# %% [markdown]
# The features Age, Cabin and Embarked have null values.

# %% [markdown]
# ### Let's examine how many have survived.

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))  # a figure with a 1x2 grid of Axes
df_train['Survived'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0])
ax[0].set_title('Survived')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# Out of 891 passengers in the training set, only around 350 survived i.e Only 38.4% of the total training set survived the crash.

# %% [markdown]
# ### Examine the Features

# %% [markdown]
# #### Categorical Feature: Sex

# %%
df_train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df_train.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))
df_train[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=df_train,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# This looks interesting. The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a women on the ship is around 75% while that for men in around 18-19%.
#
# This looks to be a very important feature for modeling. But is it the best?? Lets check other features.

# %% [markdown]
# #### Ordinal Feature : Pclass

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=df_train)
plt.show()

# %% [markdown]
# It looks like female in Pclass 1 and Pclass 2 had a pretty high survival rate. However, for male the Pclass type did not affect the survival rate that much.

# %%
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=df_train)

# %% [markdown]
# ### Explore how age affects survival
# To simply and visualize how different ranges of age have affected survival, categorize the range of age.
# First, let's double Check if there's a negative number in the Age column.

# %%
any(df_train['Age']<0)
# Out:
# False

# %%
ar = df_train['Age'].isnull().values    
    
def get_category(age):
    cat=''
    for i in range(len(ar)):
        if ar[i]:
            cat = 'Unknown'
        else:
            if age <=5:
                cat = 'Baby'
            elif age <=12:
                cat = 'Child'
            elif age <=18:
                cat = 'Teenager'
            elif age <=25:
                cat = 'Student'
            elif age <=35:
                cat = 'Young Adult'
            elif age <=60:
                cat = 'Adult'
            else: 
                cat = 'Elderly'        
    return cat

plt.figure(figsize=(8,5))

group_names = ['Unknown','Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Elderly']
df_train['Age_cat'] = df_train['Age'].apply(lambda x: get_category(x))
sns.barplot(x='Age_cat', y='Survived', hue='Sex', data=df_train, order=group_names)  
df_train.drop('Age_cat', axis=1, inplace=True)

# %% [markdown]
# Did age affect survival rate? It seems that age did not matter for female overall except for the Child age band which unusually had a lower survial rate than that of the male. For male, age did matter. Babies and children had a higher survial rate than the older aged people.

# %% [markdown]
# As we had seen earlier, the Age feature has 177 null values. To replace these NaN values, we can assign them the mean age of the dataset.
#
# But the problem is, there were many people with many different ages. We just can't assign a 4 year kid with the mean age that is 29 years. Is there any way to find out what age-band does the passenger lie??
#
# Bingo!!!!, we can check the Name feature. Looking upon the feature, we can see that the names have a salutation like Mr or Mrs. Thus we can assign the mean values of Mr and Mrs to the respective groups.
#
# ''What's In A Name??''---> Feature :p

# %%
df_train['Initial'] = 0
for i in df_train:
    df_train['Initial']=df_train.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
pd.crosstab(df_train.Initial,df_train.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_de47a4be_1df9_11ea_b1ed_acde48001122row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_de47a4be_1df9_11ea_b1ed_acde48001122" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de47a4be_1df9_11ea_b1ed_acde48001122level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_de47a4be_1df9_11ea_b1ed_acde48001122row0_col13" class="data row0 col13" >125</td>
#                         <t

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
df_train['Initial'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
df_train.groupby('Initial')['Age'].mean() #let's check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'),'Age']=33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age']=36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age']=5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age']=22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age']=46

# %%
df_train.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))
df_train[df_train['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
df_train[df_train['Survived']==1].Age.plot.hist(ax=ax[1],color='blue',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=df_train)
plt.show()

# %% [markdown]
# The Women and Child first policy thus holds true irrespective of the class.

# %% [markdown]
# ### Categorical Feature: Embarked

# %%
pd.crosstab([df_train.Embarked,df_train.Pclass],[df_train.Sex,df_train.Survived],margins=True). \
style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e0815a4a_1df9_11ea_b1ed_acde48001122row0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row0_col1 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row0_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row0_col3 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row0_col4 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row1_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row1_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row1_col3 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row1_col4 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row2_col0 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row2_col2 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row2_col3 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row2_col4 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row4_col1 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row5_col0 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row5_col1 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row5_col2 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row5_col3 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row5_col4 {
#             background-color:  #ebf566;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row6_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row6_col1 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row6_col2 {
#             background-color:  #e4f266;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row6_col3 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row6_col4 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row7_col0 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row7_col1 {
#             background-color:  #bdde66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row7_col2 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row7_col3 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row7_col4 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row8_col0 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row8_col1 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row8_col2 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row8_col3 {
#             background-color:  #b0d866;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row8_col4 {
#             background-color:  #9acc66;
#             color:  #000000;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row9_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row9_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row9_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row9_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e0815a4a_1df9_11ea_b1ed_acde48001122row9_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e0815a4a_1df9_11ea_b1ed_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0815a4a_1df9_11ea_b1ed_acde48001122level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_e0815a4a_1df9_11ea_b1ed_acde48001122level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_e0815a4a_1df9_11ea_b

# %%
sns.factorplot('Embarked','Survived',data=df_train)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# The chances for survival for Port C is highest around 0.55 while it is lowest for S.

# %%
f,ax=plt.subplots(2,2,figsize=(15,6))
sns.countplot('Embarked',data=df_train,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=df_train,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=df_train,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=df_train,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=df_train)
plt.show()

# %% [markdown]
# #### Filling Embarked NaN
# As we saw that maximum passengers boarded from Port S, we replace NaN with S.

# %%
df_train['Embarked'].fillna('S', inplace=True)

# %%
df_train.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %% [markdown]
# ### Discrete Feature: Sibsip

# %%
pd.crosstab([df_train.SibSp],df_train.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e2148bca_1df9_11ea_b1ed_acde48001122row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row3_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row4_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row4_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_e2148bca_1df9_11ea_b1ed_acde48001122row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_e2148bca_1df9_11ea_b1ed_acde48001122" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e2148bca_1df9_11ea_b1ed_acde48001122level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_e2148bca_1df9_11ea_b1ed_acde48001122row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
sns.barplot('SibSp','Survived',data=df_train)
plt.show()

# %%
pd.crosstab(df_train.SibSp,df_train.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row2_col1 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row2_col2 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row3_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row3_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row3_col2 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row4_col2 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_e2c0bfb2_1df9_11ea_b1ed_acde48001122row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Discrete Feature: Parch

# %%
pd.crosstab(df_train.Parch,df_train.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e407adc2_1df9_11ea_b1ed_acde48001122row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row1_col0 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row1_col1 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row1_col2 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row2_col0 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row2_col1 {
#             background-color:  #e1f066;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row2_col2 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row3_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row3_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row4_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row4_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row5_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e407adc2_1df9_11ea_b1ed_acde48001122row6_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_e407adc2_1df9_11ea_b1ed_acde48001122" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row0_col0" class="data row0 col0" >163</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row0_col1" class="data row0 col1" >134</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row0_col2" class="data row0 col2" >381</td>
#             </tr>
#             <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row1_col0" class="data row1 col0" >31</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row1_col1" class="data row1 col1" >32</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row1_col2" class="data row1 col2" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row2_col0" class="data row2 col0" >21</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row2_col1" class="data row2 col1" >16</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row2_col2" class="data row2 col2" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row3_col1" class="data row3 col1" >2</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row3_col2" class="data row3 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_e407adc2_1df9_11ea_b1ed_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_e407adc2_1df9_11ea_b1ed_acde48001122row6_col2" class="data row6 col2" >1</td>
#             </tr>
#     </tbody></table>

# %%
sns.barplot('Parch','Survived',data=df_train)
plt.show()

# %% [markdown]
# The chances of survival is good for somebody who has 1-3 parents on the ship. Being alone also proves to be fatal and the chances for survival decreases when somebody has >4 parents on the ship.

# %% [markdown]
# ### Continuous Feature: Fare

# %%
print('Highest Fare was:',df_train['Fare'].max())
print('Lowest Fare was:',df_train['Fare'].min())
print('Average Fare was:',df_train['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(df_train[df_train['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(df_train[df_train['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(df_train[df_train['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also continous, we can convert into discrete values by using binning.

# %%
# Correlation between the features
sns.heatmap(df_train.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# ## Part2: Feature Engineering and Data Cleaning
# Now what is Feature Engineering?
#
# Whenever we are given a dataset with features, it is not necessary that all the features will be important. There maybe be many redundant features which should be eliminated. Also we can get or add new features by observing or extracting information from other features.
#
# An example would be getting the Initals feature using the Name Feature. Lets see if we can get any new features and eliminate a few. Also we will tranform the existing relevant features to suitable form for Predictive Modeling.

# %%
df_train['Age'].fillna(df_train['Age'].mean(),inplace=True)
df_train['Cabin'].fillna('N',inplace=True)
df_train['Embarked'].fillna('N',inplace=True)
print('데이터 세트 Null 값 갯수 ',df_train.isnull().sum().sum())
# Out:
# 데이터 세트 Null 값 갯수  0

# %%
from sklearn import preprocessing

def encode_features(dataDF):
    features = ['Cabin', 'Sex', 'Embarked']
    for feature in features:
        le = preprocessing.LabelEncoder()
        le = le.fit(dataDF[feature])
        dataDF[feature] = le.transform(dataDF[feature])
        
    return dataDF

df_train = encode_features(df_train)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Cabin  Embarked Initial
# 0         A/5 21171   7.2500    146         3      Mr
# 1          PC 17599  71.2833     81         0     Mrs
# 2  STON/O2. 3101282   7.9250    146         3    Miss
# 3            113803  53.1000     55         3     Mrs
# 4            373450   8.0500    146         3      Mr

# %%
from sklearn.preprocessing import LabelEncoder

def fillna(df):
    df['Age'].fillna(df['Age'].mean(), inplace=True)
    df['Cabin'].fillna('N',inplace=True)
    df['Embarked'].fillna('N',inplace=True)
    df['Fare'].fillna(0,inplace=True)
    return df

# We assume thease features won't be useful.
def drop_features(df):
    df.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)
    return df

def format_features(df):
    df['Cabin'] = df['Cabin'].str[:1]
    features = ['Cabin','Sex','Embarked']
    for feature in features:
        le=LabelEncoder()
        le=le.fit(df[feature])
        df[feature]=le.transform(df[feature])
    return df

def transform_features(df):
    df=fillna(df)
    df=drop_features(df)
    df=format_features(df)
    return df

# %% [markdown]
# ## 3. Predictive Modeling

# %%
titanic_df = pd.read_csv('train.csv')
y_titanic_df = titanic_df['Survived']
X_titanic_df = titanic_df.drop('Survived', axis=1)
X_titanic_df = transform_features(X_titanic_df)

# %% [markdown]
# To evaluate the performance of any machine learning model we need to test it on some unseen data.  Cross validation (CV) is one of the techniques used to test the effectiveness of a machine learning model. We will use the train-test split approach and the K-folds Cross Validation Approach.

# %%
# train-test split approach
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_titanic_df, y_titanic_df, \
                                                  test_size=0.2, random_state=11)

# %% [markdown]
# With the above train-test split approach, there is a possibility of a high bias if we have limited data, because we would miss some information about the data which we have not used for training. If our data is huge and our test sample and train sample has the same distribution then this approach could be acceptable.

# %%
from sklearn import svm #support vector Machine
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.metrics import accuracy_score
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %% [markdown]
# ### Support Vector Machine

# %%
svm_clf = svm.SVC(kernel='linear',C=0.1,gamma=0.1)
svm_clf.fit(X_train , y_train)
svm_pred = svm_clf.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
print(f'Accuracy for linear SVM is: {svm_accuracy:.4f}')
# Out:
# Accuracy for linear SVM is: 0.8324

# %% [markdown]
# ### Logistic Regression

# %%
lr_clf = LogisticRegression()
lr_clf.fit(X_train , y_train)
lr_pred = lr_clf.predict(X_test)
lr_accuracy = accuracy_score(y_test, lr_pred)
print(f'Accuracy for logistic Regression: {lr_accuracy:.4f}')
# Out:
# Accuracy for logistic Regression: 0.8659

# %% [markdown]
# ### Decision Tree

# %%
dt_clf = DecisionTreeClassifier(random_state=11)
dt_clf.fit(X_train , y_train)
dt_pred = dt_clf.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print(f'DecisionTree Accuracy: {dt_accuracy:.4f}')
# Out:
# DecisionTree Accuracy: 0.7877

# %% [markdown]
# ### Random Forest

# %%
rf_clf = RandomForestClassifier(random_state=11)
rf_clf.fit(X_train , y_train)
rf_pred = rf_clf.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print(f'Random Forest Accuracy: {rf_accuracy:.4f}')
# Out:
# Random Forest Accuracy: 0.8324

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# Many a times, the data is imbalanced, i.e there may be a high number of class1 instances but less number of other class instances. Thus we should train and test our algorithm on each and every instance of the dataset. Then we can take an average of all the noted accuracies over the dataset.
#
# 1)The K-Fold Cross Validation works by first dividing the dataset into k-subsets.
#
# 2)Let's say we divide the dataset into (k=5) parts. We reserve 1 part for testing and train the algorithm over the 4 parts.
#
# 3)We continue the process by changing the testing part in each iteration and training the algorithm over the other parts. The accuracies and errors are then averaged to get a average accuracy of the algorithm.
#
# This is called K-Fold Cross Validation.
#
# 4)An algorithm may underfit over a dataset for some training data and sometimes also overfit the data for other training set. Thus with cross-validation, we can achieve a generalised model.

# %% [markdown]
# K-Fold is popular and easy to understand. It generally results in a less biased model compared to other methods. Because it ensures that every observation from the original dataset has the chance of appearing in both the training and the test set, it is one of the best approaches if we have limited input data.

# %% [markdown]
# ![K-Folds%20Cross%20Validation.png](attachment:K-Folds%20Cross%20Validation.png)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score   # For the StratifiedKfold, use cross_val_score API
from sklearn.model_selection import cross_val_predict 

kfold = KFold(n_splits=5, random_state=22) # k=5, split the data into 5 equal parts
xyz=[]
accuracy=[]
std=[]
classifiers=['Linear Svm','Logistic Regression','Decision Tree','Random Forest']
models=[svm.SVC(kernel='linear'),LogisticRegression(),DecisionTreeClassifier(),RandomForestClassifier(n_estimators=100)]
for i in models:
    cv_result = cross_val_score(i,X_titanic_df,y_titanic_df, cv = kfold,scoring = "accuracy")
    xyz.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2=pd.DataFrame({'CV Mean':xyz,'Std':std},index=classifiers)       
new_models_dataframe2
# Out:
#                       CV Mean       Std
# Linear Svm           0.787848  0.028269
# Logistic Regression  0.790120  0.031118
# Decision Tree        0.783429  0.023573
# Random Forest        0.801394  0.038727

# %%
plt.subplots(figsize=(12,6))
box=pd.DataFrame(accuracy,index=[classifiers])
box.T.boxplot()
